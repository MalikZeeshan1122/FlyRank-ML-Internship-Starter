# %% [markdown]
# <a href="https://colab.research.google.com/github/MalikZeeshan1122/FlyRank-ML-Internship-Starter/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MalikZeeshan1122/FlyRank-ML-Internship-Starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Lane: Content refresh opportunities")
print("Goal: Measure page-level patterns related to organic search performance.")
# Out:
# Lane: Content refresh opportunities
# Goal: Measure page-level patterns related to organic search performance.

# %%
import os

print("Current directory:")
print(os.getcwd())

print("\nFiles/folders here:")
print(os.listdir())
# Out:
# Current directory:
# /content
#
# Files/folders here:
# ['.config', 'sample_data']

# %%
['flyrank-ml-internship-starter', ...]
# Out:
# ['flyrank-ml-internship-starter', Ellipsis]

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter.git
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 299, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 299 (delta 130), reused 98 (delta 98), pack-reused 106 (from 1)
# Receiving objects: 100% (299/299), 1.88 MiB | 4.81 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import pandas as pd

csv_path = "flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"

print("File exists:", os.path.exists(csv_path))

df = pd.read_csv(csv_path)

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Column names:", df.columns.tolist())
# Out:
# File exists: True
# Rows: 30000
# Columns: 44
# Column names: ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Quick data check

print("Rows:", len(df))
print("Columns:", len(df.columns))

print(
    "Median content age (days):",
    df["content_age_days"].median()
)

print(
    "Median days since last update:",
    df["days_since_last_update"].median()
)

print(
    "Pages with impressions in last 30 days:",
    (df["impressions_last_30d"] > 0).sum()
)
# Out:
# Rows: 30000
# Columns: 44
# Median content age (days): 236.0
# Median days since last update: 20.0
# Pages with impressions in last 30 days: 27453

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

print("Claim scope check:")
print("- Observed: page-level patterns in the available dataset")
print("- Measured: statistics and model evaluation metrics")
print("- Directional: signals may support prioritization")
print("- Decision-support: recommendations require human review")
print("- Not causal proof")
print("- Not a prediction of Google's ranking decisions")
# Out:
# Claim scope check:
# - Observed: page-level patterns in the available dataset
# - Measured: statistics and model evaluation metrics
# - Directional: signals may support prioritization
# - Decision-support: recommendations require human review
# - Not causal proof
# - Not a prediction of Google's ranking decisions

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
